# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravind-6646/Data-Analytics-and-Visualization/blob/main/mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', 'CineMetrics_Dataset.xlsx', 'sample_data']

# %%
import pandas as pd

data = pd.read_excel('/content/CineMetrics_Dataset.xlsx')
data.head()
# Out:
#    Movie_ID                  Title        Genre  Release_Year  Duration_Min  \
# 0         1    The Crimson Odyssey    Animation          2013           NaN
# 1         2        The Sacred Echo  Documentary          2014          88.0
# 2         3    The Rising Illusion       Action          1995         105.0
# 3         4  The Crimson Awakening       Sci-Fi          2003         107.0
# 4         5        The Last Legacy       Sci-Fi          2020          82.0
#
#   Language  Country Streaming_Platform  Budget_Million_USD  \
# 0   French   France            HBO Max                33.8
# 1    Hindi    India        Prime Video                58.4
# 2  Spanish   Mexico            HBO Max                12.8
# 3   German  Germany            Netflix                11.4
# 4    Hindi    India            Netflix                37.1
#
#    Revenue_Million_USD  IMDB_Rating  Votes_Thousands  Critic_Score  \
# 0                 43.9          3.6            315.9          46.0
# ...

# %%
data
# Out:
#      Movie_ID                  Title        Genre  Release_Year  Duration_Min  \
# 0           1    The Crimson Odyssey    Animation          2013           NaN
# 1           2        The Sacred Echo  Documentary          2014          88.0
# 2           3    The Rising Illusion       Action          1995         105.0
# 3           4  The Crimson Awakening       Sci-Fi          2003         107.0
# 4           5        The Last Legacy       Sci-Fi          2020          82.0
# ..        ...                    ...          ...           ...           ...
# 295       296      The Fading Mirage      Romance          2021         141.0
# 296       297     The Sacred Journey      Fantasy          2014         110.0
# 297       298  The Burning Rebellion  Documentary          2006         158.0
# 298       299     The Fading Descent       Comedy          1999         114.0
# 299       300     The Eternal Legacy      Romance          2015         148.0
#
# ...

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_ID                   300 non-null    int64
#  1   Title                      300 non-null    object
#  2   Genre                      288 non-null    object
#  3   Release_Year               300 non-null    int64
#  4   Duration_Min               285 non-null    float64
#  5   Language                   291 non-null    object
#  6   Country                    300 non-null    object
#  7   Streaming_Platform         291 non-null    object
#  8   Budget_Million_USD         264 non-null    float64
#  9   Revenue_Million_USD        273 non-null    float64
#  10  IMDB_Rating                282 non-null    float64
#  11  Votes_Thousands            285 non-null    float64
#  12  Critic_Score               279 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# Movie_ID                      0
# Title                         0
# Genre                        12
# Release_Year                  0
# Duration_Min                 15
# Language                      9
# Country                       0
# Streaming_Platform            9
# Budget_Million_USD           36
# Revenue_Million_USD          27
# IMDB_Rating                  18
# Votes_Thousands              15
# Critic_Score                 21
# Director_Experience_Years    12
# dtype: int64

# %%
data[data.isnull().any(axis=1)]
# Out:
#      Movie_ID                  Title        Genre  Release_Year  Duration_Min  \
# 0           1    The Crimson Odyssey    Animation          2013           NaN
# 1           2        The Sacred Echo  Documentary          2014          88.0
# 4           5        The Last Legacy       Sci-Fi          2020          82.0
# 7           8  The Shattered Kingdom        Drama          2004         161.0
# 15         16     The Crimson Voyage       Comedy          2011         110.0
# ..        ...                    ...          ...           ...           ...
# 287       288    The Distant Paradox    Animation          2018         159.0
# 288       289       The Last Odyssey     Thriller          2005         142.0
# 291       292   The Frozen Rebellion     Thriller          2007         105.0
# 293       294      The Distant Storm      Fantasy          1997         110.0
# 297       298  The Burning Rebellion  Documentary          2006         158.0
#
# ...

# %%
data['Duration_Min'] = data['Duration_Min'].fillna(0)
data
# Out:
#      Movie_ID                  Title        Genre  Release_Year  Duration_Min  \
# 0           1    The Crimson Odyssey    Animation          2013           0.0
# 1           2        The Sacred Echo  Documentary          2014          88.0
# 2           3    The Rising Illusion       Action          1995         105.0
# 3           4  The Crimson Awakening       Sci-Fi          2003         107.0
# 4           5        The Last Legacy       Sci-Fi          2020          82.0
# ..        ...                    ...          ...           ...           ...
# 295       296      The Fading Mirage      Romance          2021         141.0
# 296       297     The Sacred Journey      Fantasy          2014         110.0
# 297       298  The Burning Rebellion  Documentary          2006         158.0
# 298       299     The Fading Descent       Comedy          1999         114.0
# 299       300     The Eternal Legacy      Romance          2015         148.0
#
# ...

# %%
data['Duration_Min'] = data['Duration_Min'].fillna(data['Duration_Min'].mean())
data
# Out:
#      Movie_ID                  Title        Genre  Release_Year  Duration_Min  \
# 0           1    The Crimson Odyssey    Animation          2013           0.0
# 1           2        The Sacred Echo  Documentary          2014          88.0
# 2           3    The Rising Illusion       Action          1995         105.0
# 3           4  The Crimson Awakening       Sci-Fi          2003         107.0
# 4           5        The Last Legacy       Sci-Fi          2020          82.0
# ..        ...                    ...          ...           ...           ...
# 295       296      The Fading Mirage      Romance          2021         141.0
# 296       297     The Sacred Journey      Fantasy          2014         110.0
# 297       298  The Burning Rebellion  Documentary          2006         158.0
# 298       299     The Fading Descent       Comedy          1999         114.0
# 299       300     The Eternal Legacy      Romance          2015         148.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_ID                   300 non-null    int64
#  1   Title                      300 non-null    object
#  2   Genre                      288 non-null    object
#  3   Release_Year               300 non-null    int64
#  4   Duration_Min               300 non-null    float64
#  5   Language                   291 non-null    object
#  6   Country                    300 non-null    object
#  7   Streaming_Platform         291 non-null    object
#  8   Budget_Million_USD         264 non-null    float64
#  9   Revenue_Million_USD        273 non-null    float64
#  10  IMDB_Rating                282 non-null    float64
#  11  Votes_Thousands            285 non-null    float64
#  12  Critic_Score               279 non-null    float64
# ...

# %%
numeric_col=['Budget_Million_USD','Revenue_Million_USD','IMDB_Rating','Votes_Thousands','Critic_Score','Director_Experience_Years']
for col in numeric_col:
  data[col]=data[col].fillna(data[col].mean())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_ID                   300 non-null    int64
#  1   Title                      300 non-null    object
#  2   Genre                      288 non-null    object
#  3   Release_Year               300 non-null    int64
#  4   Duration_Min               300 non-null    float64
#  5   Language                   291 non-null    object
#  6   Country                    300 non-null    object
#  7   Streaming_Platform         291 non-null    object
#  8   Budget_Million_USD         300 non-null    float64
#  9   Revenue_Million_USD        300 non-null    float64
#  10  IMDB_Rating                300 non-null    float64
#  11  Votes_Thousands            300 non-null    float64
#  12  Critic_Score               300 non-null    float64
# ...

# %%
data
# Out:
#      Movie_ID                  Title        Genre  Release_Year  Duration_Min  \
# 0           1    The Crimson Odyssey    Animation          2013           0.0
# 1           2        The Sacred Echo  Documentary          2014          88.0
# 2           3    The Rising Illusion       Action          1995         105.0
# 3           4  The Crimson Awakening       Sci-Fi          2003         107.0
# 4           5        The Last Legacy       Sci-Fi          2020          82.0
# ..        ...                    ...          ...           ...           ...
# 295       296      The Fading Mirage      Romance          2021         141.0
# 296       297     The Sacred Journey      Fantasy          2014         110.0
# 297       298  The Burning Rebellion  Documentary          2006         158.0
# 298       299     The Fading Descent       Comedy          1999         114.0
# 299       300     The Eternal Legacy      Romance          2015         148.0
#
# ...
